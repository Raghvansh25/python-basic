# %% [markdown]
# # Python basic

# %%
Que. 1 What is Python, and why is it popular ?
->   Python is a high level intrepreting programing language
 python is poular because
 1.it is easy to available and easy to learn
2. lot of liabararies are available for a coding
3.huge action community are available

Que.2 What is an interpreter in Python ?
-> a intrepreter in python are read and execute code line by line and translating machine code and it is easy to helpful for computer  understanding  code

Que3. What are pre-defined keywords in Python ?
-> prtedefined keyword is special words in python that are specificic meaning and uses in python.
eg. true,false,import

Que.4 Can keywords be used as variable names ?
->  No, keywords are not used in varibale names because they have special nd specific meaning.

Que.5 What is mutability in Python?
-> Mutability means inn python whether or not an object’s value can be changed after it is created

Que.6 Why are lists mutable, but tuples are immutable ?
-> because in list its easy changes can do after creation & tuples are immuatable because it is design choices are flexiblity perofrmance and data safety

Que.7 What is the difference between “==” and “is” operators in Python?
-> "=="& "is" both are operaters used i comparision in python
"==" used for equality operator compared the containts of two varible if values are equal
"is"used for identity operator for compared the two varibale are same in memory location

Que.8 What are logical operators in Python ?
-> Logical opertor are used in python for combine used statements evaluate to true or false for applied statements condtion
eg. and, or, not

Que.9 What is type casting in Python?
-> Casting is the process of chnaging the data type of value or object
there is two type of casting in python
1.implicit
2. explicit

 Que.10 What is the difference between implicit and explicit type casting ?
 -> in implict python automatically understand given value to integer
 in explicit string value convert into float

 Que.11 What is the purpose of conditional statements in Python ?
 -> flow control in python refers to the mechanism that governs order in which statements & instructions are executed this crucial for imlimating logic in our program.

 que.12 How does the elif statement work ?
 -> if elif (else) >> two conditions
 in real life we have multiple conditions
 #syntax
 #if same condtion
 #elif same condition
 # else

 Que.13 What is the difference between for and while loops?
 -> while loops are repeatedly executed a b;ock of code untill condition are met
 for loop interate over a sequence of elements

 Que.14 Describe a scenario where a while loop is more suitable than a for loop?
 -> user login scenario
 in user login login id and password keep trying van use correct id and password
 orrect_password = "secure123"
attempts = 0
max_attempts = 3

while attempts < max_attempts:
    entered_password = input("Enter your password: ")
    if entered_password == correct_password:
        print("Access granted.")
        break
    else:
        attempts += 1
        print(f"Incorrect password. Attempts left: {max_attempts - attempts}")

if attempts == max_attempts:
    print("Access denied. Too many failed attempts.")
    You don’t know how many attempts it will take (could be 1, 2, or 3).

The loop depends on a condition (attempts < max_attempts) rather than a fixed range.

A for loop would be less intuitive here because it's designed for a known number of iterations — while in this case, you might exit early if the password is correct.

# %% [markdown]
# practical Questions

# %%
Que.1 Write a Python program to print print "Hello, World!"
-> print("Hello, World!"

Que.2  Write a Python program that displays your name and age
-> print("Manoj,30")

Que.3 Write code to print all the pre-defined keywords in Python using the keyword library?
->  import keywordlist

Que.4 Write a program that checks if a given word is a Python keyword.
-> if keyword.iskeyword(word):

Que.5 Create a list and tuple in Python, and demonstrate how attempting to change an element works differently
for each.
-> # Creating a list
my_list = [1, 2, 3]

# Creating a tuple
my_tuple = (1, 2, 3)

Que.6 Write a function to demonstrate the behavior of mutable and immutable arguments.
        def modify (immutable_arg, mutable_arg):

         convert into int
         immutable_arg += 10
modify the mutable argument into list
          mutable_arg.append(4)
          print("inside function":
          print("immutable argument":
          print("mutable argument":

  #immutable argument (int)
  a=5
  # mutable argument (list)
  b=[1,2,3,4]

    modifyargumets(ab)


Que.7 Write a program that performs basic arithmetic operations on two user-input numbers
 -> # Basic Arithmetic Operations Program

# Taking input from the user
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

# Performing operations
addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2

# Handling division by zero
if num2 != 0:
    division = num1 / num2
else:
    division = "Undefined (cannot divide by zero)"


Que.8 Write a program to demonstrate the use of logical operators.
  # Logical Operators Example

# Define two variables
a = 10
b = 5

# Using 'and' operator
print("a > 5 and b < 10:", a > 5 and b < 10)  # True and True -> True

# Using 'or' operator
print("a < 5 or b < 10:", a < 5 or b < 10)    # False or True -> True

# Using 'not' operator
print("not(a > b):", not(a > b))              # not(True) -> False

# Additional examples
x = True
y = False

print("x and y:", x and y)
print("x or y:", x or y)
print("not x:", not x)

que.9 Create a list and tuple in Python, and demonstrate how attempting to change an element works differently
for each.

-> my_list = [10, 20, 30]
print("Original list:", my_list)

# Changing the second element (index 1)
my_list[1] = 200
print("Modified list:", my_list)

Que.10 Write a Python program to convert user input from string to integer, float, and boolean types.
-> # Get input from the user
user_input = input("Enter a value: ")

# Convert to integer
try:
    int_value = int(user_input)
    print("Integer value:", int_value)
except ValueError:
    print("Cannot convert to integer.")

# Convert to float
try:
    float_value = float(user_input)
    print("Float value:", float_value)
except ValueError:
    print("Cannot convert to float.")

# Convert to boolean
# In Python, any non-empty string is True, but we interpret common inputs for clarity
true_values = ['true', '1', 'yes', 'on']
false_values = ['false', '0', 'no', 'off']

input_lower = user_input.strip().lower()
if input_lower in true_values:
    bool_value = True
    print("Boolean value: True")
elif input_lower in false_values:
    bool_value = False
    print("Boolean value: False")
else:
    print("Cannot clearly convert to boolean (use 'true/false', 'yes/no', etc.).")

Que.11 Write code to demonstrate type casting with list elements.
  -># Original list with string numbers
string_list = ['1', '2', '3', '4', '5']

# Display original list and types
print("Original list:", string_list)
print("Types before casting:", [type(element) for element in string_list])

# Convert string elements to integers using type casting
int_list = [int(element) for element in string_list]

# Display converted list and types
print("Converted list:", int_list)
print("Types after casting:", [type(element) for element in int_list])

Que.12 Write a program that checks if a number is positive, negative, or zero.
-> num = float(input("Enter a number: "))

# Check the condition
if num > 0:
    print("The number is positive.")
elif num < 0:
    print("The number is negative.")
else:
    print("The number is zero.")

Que.13 Write a for loop to print numbers from 1 to 10
                for i in range(1, 11):
    print(i)

Que.14 Write a Python program to find the sum of all even numbers between 1 and 50.
-> for i in range (50)
if i%21=1
  continue
print(i)

Que.15 Write a Python program to calculate the factorial of a number provided by the user using a while loop
      # Get input from user
num = int(input("Enter a number to calculate its factorial: "))

# Initialize variables
factorial = 1
i = 1

# Check if the number is negative
if num < 0:
    print("Factorial is not defined for negative numbers.")
else:
    while i <= num:
        factorial *= i
        i += 1
    print(f"The factorial of {num} is {factorial}")
# Out:
#   File "<ipython-input-2-3147672608>", line 1
#     Que.1 Write a Python program to print print "Hello, World!"
#        ^
# SyntaxError: invalid syntax
